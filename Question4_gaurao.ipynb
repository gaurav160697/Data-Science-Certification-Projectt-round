# %%
#Question 4
# Student Attendance Dashboard for Decision Making. You will be given a
# Google Sheet with different sheets holding data of different classes. Create
# a dashboard showing a summary of what's happening across different
# classes. Which students need attention for missing sessions? Which

# students are unsatisfied? Which students are very satisfied? <Date>
# Column shows attendance. R-<Date> Column shows the rating by the
# candidate. Extra marks for identifying more useful insights. Missing values
# of the Type column can be treated as STUDENT. This data gets updated on
# a daily basis. The latest data gets injected in early columns. Your code
# shouldn't need any changes to deal with the latest data. Please note:
# Visualisation is mandatory. You will receive 0 marks if you do not add
# visualisation. Data Link -
# https://docs.google.com/spreadsheets/d/1Y_g6LQI2GLqpKf-fj-rH7D9gfnP2
# MJzpFA6t0AsBMi8/edit?usp=sharing

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Importing class2 dataset
df1 = pd.read_csv("Batchwise Attendance Data - Class 1.csv")

# Importing class2 dataset
df2 = pd.read_csv("Batchwise Attendance Data - Class 2.csv")

# %%
df1.head()
# Out:
#    Student Roll Num     Type 10-01-21  R-10-01-21 09-01-21  R-9-01-21
# 0                 1  WORKING   Missed          10   Missed          6  \
# 1                 2      NaN   Missed           7   Missed          7
# 2                 3  STUDENT   Missed          10   Missed          8
# 3                 4  STUDENT   Missed           9   Missed         10
# 4                 5  WORKING   Missed           6   Missed          7
#
#    08-01-21  R-8-01-21  07-01-21  R-7-01-21  ...  05-01-21  R-5-01-21
# 0    Missed         10    Missed          8  ...    Missed          7  \
# 1    Missed          5  Attended         10  ...  Attended          9
# 2    Missed          6    Missed          8  ...  Attended          8
# 3  Attended          5    Missed          7  ...    Missed          6
# 4    Missed          7    Missed          8  ...    Missed         10
#
#    04-01-21  R-4-01-21  03-01-21  R-3-01-21  02-01-21  R-02-01-21  01-01-21
# ...

# %%
df2.head()
# Out:
#    Student Roll Num     Type  10-01-21  R-10-01-21  09-01-21  R-9-01-21
# 0                 1      NaN  Attended           8  Attended          7  \
# 1                 2      NaN  Attended           9  Attended         10
# 2                 3  STUDENT    Missed           5    Missed         10
# 3                 4      NaN  Attended           6  Attended          6
# 4                 5  WORKING  Attended           5  Attended          9
#
#    08-01-21  R-8-01-21  07-01-21  R-7-01-21  06-01-21  R-6-01-21  05-01-21
# 0  Attended          5  Attended          7  Attended          5  Attended  \
# 1  Attended          8  Attended          7  Attended          7  Attended
# 2    Missed          7    Missed          5    Missed          9    Missed
# 3  Attended          7  Attended          8    Missed         10    Missed
# 4  Attended          5    Missed          6    Missed          7    Missed
#
#    R-5-01-21  04-01-21  R-4-01-21  03-01-21  R-3-01-21  01-01-21  R-01-01-21
# ...

# %%
df1["Type"].fillna("STUDENT", inplace=True)
df2["Type"].fillna("STUDENT", inplace=True)

# %%
df1["Type"].isna().sum()
# Out:
# 0

# %%
df2["Type"].isna().sum()
# Out:
# 0

# %%
df1.shape
# Out:
# (57, 22)

# %%
df2.shape
# Out:
# (70, 20)

# %%
df1.isna().sum()
# Out:
# Student Roll Num    0
# Type                0
# 10-01-21            0
# R-10-01-21          0
# 09-01-21            0
# R-9-01-21           0
# 08-01-21            0
# R-8-01-21           0
# 07-01-21            1
# R-7-01-21           0
# 06-01-21            1
# R-6-01-21           0
# 05-01-21            1
# R-5-01-21           0
# 04-01-21            1
# R-4-01-21           0
# 03-01-21            1
# R-3-01-21           0
# 02-01-21            1
# R-02-01-21          0
# 01-01-21            1
# R-01-01-21          0
# dtype: int64

# %%
df1["07-01-21"].bfill(limit=1, axis=0, inplace = True)
df1["06-01-21"].bfill(limit=1, axis=0, inplace = True)
df1["05-01-21"].bfill(limit=1, axis=0, inplace = True)
df1["04-01-21"].bfill(limit=1, axis=0, inplace = True)
df1["03-01-21"].bfill(limit=1, axis=0, inplace = True)
df1["02-01-21"].bfill(limit=1, axis=0, inplace = True)
df1["01-01-21"].bfill(limit=1, axis=0, inplace = True)
df1.isna().sum()
# Out:
# Student Roll Num    0
# Type                0
# 10-01-21            0
# R-10-01-21          0
# 09-01-21            0
# R-9-01-21           0
# 08-01-21            0
# R-8-01-21           0
# 07-01-21            0
# R-7-01-21           0
# 06-01-21            0
# R-6-01-21           0
# 05-01-21            0
# R-5-01-21           0
# 04-01-21            0
# R-4-01-21           0
# 03-01-21            0
# R-3-01-21           0
# 02-01-21            0
# R-02-01-21          0
# 01-01-21            0
# R-01-01-21          0
# dtype: int64

# %%
df2.isna().sum()
# Out:
# Student Roll Num     0
# Type                 0
# 10-01-21             0
# R-10-01-21           0
# 09-01-21             0
# R-9-01-21            0
# 08-01-21             0
# R-8-01-21            0
# 07-01-21             1
# R-7-01-21            0
# 06-01-21             1
# R-6-01-21            0
# 05-01-21             1
# R-5-01-21            0
# 04-01-21             1
# R-4-01-21            0
# 03-01-21             3
# R-3-01-21            0
# 01-01-21            70
# R-01-01-21          70
# dtype: int64

# %%
df2["07-01-21"].bfill(limit=1, axis=0, inplace = True)
df2["06-01-21"].bfill(limit=1, axis=0, inplace = True)
df2["05-01-21"].bfill(limit=1, axis=0, inplace = True)
df2["04-01-21"].bfill(limit=1, axis=0, inplace = True)
df2["03-01-21"].bfill(limit=1, axis=0, inplace = True)

df2.isna().sum()
# Out:
# Student Roll Num     0
# Type                 0
# 10-01-21             0
# R-10-01-21           0
# 09-01-21             0
# R-9-01-21            0
# 08-01-21             0
# R-8-01-21            0
# 07-01-21             0
# R-7-01-21            0
# 06-01-21             0
# R-6-01-21            0
# 05-01-21             0
# R-5-01-21            0
# 04-01-21             0
# R-4-01-21            0
# 03-01-21             0
# R-3-01-21            0
# 01-01-21            70
# R-01-01-21          70
# dtype: int64

# %%
# There are 70 students in total and on 01-01-21 there is no attendance for all the 70 members and no rating.
#lets drop the column on the date 01-01-21

# %%
df2.drop(["01-01-21", "R-01-01-21"], axis =1, inplace = True)
df2
# Out:
#     Student Roll Num     Type  10-01-21  R-10-01-21  09-01-21  R-9-01-21
# 0                  1  STUDENT  Attended           8  Attended          7  \
# 1                  2  STUDENT  Attended           9  Attended         10
# 2                  3  STUDENT    Missed           5    Missed         10
# 3                  4  STUDENT  Attended           6  Attended          6
# 4                  5  WORKING  Attended           5  Attended          9
# ..               ...      ...       ...         ...       ...        ...
# 65                66   IGNORE    Missed           6    Missed         10
# 66                67  STUDENT    Missed           6    Missed          5
# 67                68  STUDENT  Attended           9  Attended          8
# 68                69  STUDENT  Attended          10  Attended          7
# 69                70  STUDENT  Attended           7  Attended          9
#
#     08-01-21  R-8-01-21  07-01-21  R-7-01-21  06-01-21  R-6-01-21  05-01-21
# ...

# %% [markdown]
# # Lets have visualization for Class1 dataset

# %%
type_df1 = pd.DataFrame(df1.Type.value_counts())
type_df1
# Out:
#          count
# Type
# STUDENT     45
# WORKING      9
# IGNORE       2
# DROPOUT      1

# %%
type_counts = df1['Type'].value_counts()

labels = type_counts.index.tolist()
sizes = type_counts.values.tolist()

plt.pie(sizes, labels=labels, autopct='%1.1f%%')


plt.title('Pie Chart of Type class1')



plt.show()

# %%
#Visualiaztion for ratings based on dates

# %%
df1_ratings = [i for i in df1.columns if i.startswith('R')]
df1_dates = [i for i in df1.columns if not i.startswith('R') and i != 'Type']

# %%
#Average rating by each student
df1['Avg_rating'] = df1[df1_ratings].apply(lambda row: row.sum() / df1[df1_ratings].shape[1], axis=1)
df1.tail()
# Out:
#     Student Roll Num     Type  10-01-21  R-10-01-21  09-01-21  R-9-01-21
# 52                53  STUDENT    Missed           8    Missed          9  \
# 53                54  STUDENT  Attended           6    Missed          8
# 54                55  WORKING    Missed           8    Missed          5
# 55                56  STUDENT  Attended          10  Attended          8
# 56                57  STUDENT  Attended           8  Attended          8
#
#     08-01-21  R-8-01-21  07-01-21  R-7-01-21  ... R-5-01-21  04-01-21
# 52  Attended          5    Missed          5  ...         6  Attended  \
# 53  Attended          8  Attended         10  ...         7  Attended
# 54    Missed          7    Missed         10  ...         9  Attended
# 55  Attended          5    Missed         10  ...         7  Attended
# 56  Attended         10  Attended          5  ...         8  Attended
#
#    R-4-01-21  03-01-21 R-3-01-21  02-01-21 R-02-01-21  01-01-21 R-01-01-21
# ...

# %%
#Bar chart for the visualization of Class 1 rating based on count


sns.countplot(x=df1['Avg_rating'], data=df1, palette="tab10")


plt.title('Countplot of Average Rating class 1')


plt.show()

# %%
#The above bar chart visualizing student count's and their rating. Here out of 56 students 6% people gave 
# avarege of 7.9 rating and 6% people gave avarage pof 7.7 rating

# 8.8 rate has given 1 percentage of student

# %%
#Bar chart for the visualization of Class 1 rating based on type of the student

plt.figure(figsize=(10, 6))
sns.barplot(x=df1['Type'], y = df1["Avg_rating"], palette="viridis")


plt.title('Barplot of Average Rating for class2 based on Types')


plt.show()

# %%
df1_rating = df1[(df1["Avg_rating"]>=5) & (df1["Avg_rating"]<=10)]
df1_rating
# Out:
#     Student Roll Num     Type  10-01-21  R-10-01-21  09-01-21  R-9-01-21
# 0                  1  WORKING    Missed          10    Missed          6  \
# 1                  2  STUDENT    Missed           7    Missed          7
# 2                  3  STUDENT    Missed          10    Missed          8
# 3                  4  STUDENT    Missed           9    Missed         10
# 4                  5  WORKING    Missed           6    Missed          7
# 5                  6  STUDENT    Missed           7    Missed          9
# 6                  7  STUDENT  Attended           5  Attended          6
# 7                  8  STUDENT    Missed           8    Missed          5
# 8                  9   IGNORE    Missed          10    Missed         10
# 9                 10  STUDENT    Missed           8    Missed          8
# 10                11  STUDENT  Attended           9  Attended          9
# 11                12  STUDENT  Attended           7  Attended         10
# ...

# %%
df1_rating["Flatten_rating"]= df1_rating["Avg_rating"].astype(int)
df1_rating.head(5)
# Out:
#    Student Roll Num     Type 10-01-21  R-10-01-21 09-01-21  R-9-01-21
# 0                 1  WORKING   Missed          10   Missed          6  \
# 1                 2  STUDENT   Missed           7   Missed          7
# 2                 3  STUDENT   Missed          10   Missed          8
# 3                 4  STUDENT   Missed           9   Missed         10
# 4                 5  WORKING   Missed           6   Missed          7
#
#    08-01-21  R-8-01-21  07-01-21  R-7-01-21  ...  04-01-21  R-4-01-21
# 0    Missed         10    Missed          8  ...    Missed         10  \
# 1    Missed          5  Attended         10  ...  Attended          8
# 2    Missed          6    Missed          8  ...    Missed          8
# 3  Attended          5    Missed          7  ...  Attended         10
# 4    Missed          7    Missed          8  ...    Missed         10
#
#    03-01-21  R-3-01-21  02-01-21  R-02-01-21  01-01-21  R-01-01-21 Avg_rating
# ...

# %%
plt.figure(figsize=(12, 6))
sns.countplot(x=df1_rating['Type'], data =df1_rating, hue=df1_rating["Flatten_rating"])

plt.show()

# %%
# the above bar graph states that more number of high rating(8 and 7ratings) people belongs to "Student" and next "working"

#Therefore, higly satisfied people are Student
#Nearly 40% belongs to "student" type seems satisfied

# %%
df1_rating2 = df1[(df1["Avg_rating"]<=7)]
df1_rating2.head(3)
# Out:
#     Student Roll Num     Type  10-01-21  R-10-01-21  09-01-21  R-9-01-21
# 8                  9   IGNORE    Missed          10    Missed         10  \
# 21                22  WORKING  Attended           5  Attended          7
# 26                27  STUDENT    Missed           6    Missed          6
#
#     08-01-21  R-8-01-21  07-01-21  R-7-01-21  ... R-5-01-21  04-01-21
# 8     Missed          5    Missed          9  ...         6    Missed  \
# 21  Attended         10  Attended          7  ...         9  Attended
# 26    Missed          6  Attended          5  ...         9    Missed
#
#    R-4-01-21  03-01-21 R-3-01-21  02-01-21 R-02-01-21  01-01-21 R-01-01-21
# 8          7    Missed         5    Missed          7    Missed          5  \
# 21         5  Attended         6  Attended          5  Attended         10
# 26        10    Missed         8    Missed          5  Attended          6
#
#     Avg_rating
# 8          6.9
# 21         6.9
# 26         6.9
#
# ...

# %%
df1_rating2["Flatten_rating"]= df1_rating2["Avg_rating"].astype(int)
df1_rating2
# Out:
# C:\Users\Sindhiya\AppData\Local\Temp\ipykernel_16032\1003077873.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1_rating2["Flatten_rating"]= df1_rating2["Avg_rating"].astype(int)
#     Student Roll Num     Type  10-01-21  R-10-01-21  09-01-21  R-9-01-21
# 8                  9   IGNORE    Missed          10    Missed         10  \
# 21                22  WORKING  Attended           5  Attended          7
# 26                27  STUDENT    Missed           6    Missed          6
# 28                29  STUDENT  Attended           7  Attended          5
# 32                33  STUDENT    Missed           5    Missed          7
# 34                35  STUDENT    Missed           7    Missed          5
# ...

# %%
plt.figure(figsize=(12, 6))
sns.countplot(x=df1_rating2['Type'], data =df1_rating2, hue=df1_rating2["Flatten_rating"])

plt.show()

# %%
#all the people belongs to "Ignore" type gave rating less than of 6, and they are highly unsatisfied.

#2% of people from "working type" gave less than 6 rating, so 2% percentage from working profession are unsatisfied

#5% of people from "Student" seems unsatisfied

#people belongs to type "Ignore" seems have not attended any sessions and they gave less rating, 2% people belongs to them

# %%
# Calculate the attendance count and missed count for each type
df1['Attended_Count'] = df1[df1 == 'Attended'].count(axis=1)
df1['Missed_Count'] = df1[df1 == 'Missed'].count(axis=1)
df1["total_sessions"] = len(df1.columns)
df1['Attended_Percentage'] = (df1['Attended_Count'] / df1['total_sessions']) * 100
df1['Missed_Percentage'] = (df1['Missed_Count'] / df1['total_sessions']) * 100

df1.head(3)
# Out:
#    Student Roll Num     Type 10-01-21  R-10-01-21 09-01-21  R-9-01-21
# 0                 1  WORKING   Missed          10   Missed          6  \
# 1                 2  STUDENT   Missed           7   Missed          7
# 2                 3  STUDENT   Missed          10   Missed          8
#
#   08-01-21  R-8-01-21  07-01-21  R-7-01-21  ...  02-01-21  R-02-01-21
# 0   Missed         10    Missed          8  ...    Missed           6  \
# 1   Missed          5  Attended         10  ...  Attended           9
# 2   Missed          6    Missed          8  ...  Attended           7
#
#    01-01-21  R-01-01-21 Avg_rating  Attended_Count Missed_Count
# 0    Missed           5        7.9               0           10  \
# 1    Missed           7        7.7               4            6
# 2  Attended           8        7.8               4            6
#
#    total_sessions Attended_Percentage  Missed_Percentage
# 0              28            0.000000          35.714286
# ...

# %%
student= df1[df1['Type'] == 'STUDENT']
working = df1[df1['Type'] == 'WORKING']
ignore = df1[df1['Type'] == 'IGNORE']
dropout = df1[df1['Type'] == 'DROPOUT']

Types = ['student', 'working', 'ignore', 'dropout']

attended_percentage = [
    student['Attended_Percentage'].mean(),
    working['Attended_Percentage'].mean(),
    ignore['Attended_Percentage'].mean(),
    dropout['Attended_Percentage'].mean()
]

missed_percentage = [
    student['Missed_Percentage'].mean(),
    working['Missed_Percentage'].mean(),
    ignore['Missed_Percentage'].mean(),
    dropout['Missed_Percentage'].mean()
]


ignore.head()
# Out:
#     Student Roll Num    Type 10-01-21  R-10-01-21 09-01-21  R-9-01-21
# 8                  9  IGNORE   Missed          10   Missed         10  \
# 49                50  IGNORE   Missed           5   Missed          6
#
#    08-01-21  R-8-01-21 07-01-21  R-7-01-21  ... 02-01-21  R-02-01-21 01-01-21
# 8    Missed          5   Missed          9  ...   Missed           7   Missed  \
# 49   Missed          7   Missed          6  ...   Missed           6   Missed
#
#     R-01-01-21 Avg_rating  Attended_Count Missed_Count  total_sessions
# 8            5        6.9               0           10              28  \
# 49           6        6.4               0           10              28
#
#    Attended_Percentage  Missed_Percentage
# 8                  0.0          35.714286
# 49                 0.0          35.714286
#
# [2 rows x 28 columns]

# %%
# Set the width of each bar
bar_width = 0.3

# Set the positions of the bars on the x-axis
r1 = range(len(Types))
r2 = [x + bar_width for x in r1]

# Create the bar plot
plt.figure(figsize=(15, 6))
plt.bar(r1, attended_percentage, color="hotpink", width=bar_width, edgecolor="black", label='Attended')
plt.bar(r2, missed_percentage, color="b", width=bar_width, edgecolor="black", label='Missed')

# Add labels, title, and legend
plt.xlabel('Type')
plt.ylabel('Percentage')
plt.title('Attendance Percentage by Type')
plt.xticks([r + bar_width/2 for r in range(len(Types))], Types)
plt.legend()
# Show the plot
plt.show()

# %%
x1 = np.array(student['Attended_Percentage'].mean())
x2 = np.array(working['Attended_Percentage'].mean())
x3 = np.array(ignore['Attended_Percentage'].mean())
x4 = np.array(dropout['Attended_Percentage'].mean())

y = np.array([x1, x2, x3, x4])

Types = ['student', 'working', 'ignore', 'dropout']
mycolors = ["y", "hotpink", "b", "#4CAF50"]

plt.pie(y, labels = Types, colors = mycolors, autopct='%1.1f%%')
plt.title('Pie Chart of Total Attended')

plt.show()

# %%
#from above chart 53.7% of "Student" have attended in total sessions
#46.3% student from "Working" have attended the total sessions
#ignore and drop out occupied 0% in attendancce

# %%
y1 = np.array((student['Missed_Percentage'].mean(),
    working['Missed_Percentage'].mean(),
    ignore['Missed_Percentage'].mean(),
    dropout['Missed_Percentage'].mean()))

Types = ['student', 'working', 'ignore', 'dropout']
mycolors = ["y", "b", "r", "#4CAF50"]

plt.pie(y1, labels = Types, colors = mycolors, autopct='%1.1f%%')
plt.title('Pie Chart of Total Missed')
plt.show()

# %%
#from class1 in total count 33.7% of ignore and dropout type people have missed sessions and need to get attention
# 15% of student from type "Student" missed sessions needs to get attention
#17.6% of student from "Working" missed sessions and need attention

# %% [markdown]
# # Attendance based on each Type "Student", "Working", "Ignore" and "Dropout" for class 1

# %%
fig, (ax1,ax2,ax3,ax4) = plt.subplots(1,4,figsize=(16, 6)) 
y11 = np.array((student['Missed_Percentage'].mean(),
   student['Attended_Percentage'].mean()))
y12 = np.array((working['Missed_Percentage'].mean(), working['Attended_Percentage'].mean()))
y13 = np.array((ignore['Missed_Percentage'].mean(), ignore['Attended_Percentage'].mean()))
y14 = np.array((dropout['Missed_Percentage'].mean(), ignore['Attended_Percentage'].mean()))

Types = ["Missed", "Attended"]
mycolors = ["y", "b"]
               
ax1.pie(y11, labels = Types, colors = mycolors,autopct='%1.1f%%')
ax2.pie(y12, labels = Types, colors = mycolors,autopct='%1.1f%%')
ax3.pie(y13, labels = Types, colors = mycolors,autopct='%1.1f%%')
ax4.pie(y14, labels = Types, colors = mycolors,autopct='%1.1f%%')
plt.show()

# %% [markdown]
# # The above all the graphs provides the visualization for class1 datasets

# %% [markdown]
# # Visualization for Class2 dataset

# %%
type_df2 = pd.DataFrame(df2.Type.value_counts())
type_df2
# Out:
#          count
# Type
# STUDENT     49
# WORKING     16
# DROPOUT      3
# IGNORE       2

# %%
type_counts = df2['Type'].value_counts()

labels = type_counts.index.tolist()
sizes = type_counts.values.tolist()

plt.pie(sizes, labels=labels, autopct='%1.1f%%')


plt.title('Pie Chart of Type class2')



plt.show()

# %%
df2_ratings = [i for i in df2.columns if i.startswith('R')]
df2_dates = [i for i in df2.columns if not i.startswith('R') and i != 'Type']

# %%
#Average rating by each student
df2['Avg_rating'] = df2[df2_ratings].apply(lambda row: row.sum() / df2[df2_ratings].shape[1], axis=1)
df2.head(3)
# Out:
#    Student Roll Num     Type  10-01-21  R-10-01-21  09-01-21  R-9-01-21
# 0                 1  STUDENT  Attended           8  Attended          7  \
# 1                 2  STUDENT  Attended           9  Attended         10
# 2                 3  STUDENT    Missed           5    Missed         10
#
#    08-01-21  R-8-01-21  07-01-21  R-7-01-21  06-01-21  R-6-01-21  05-01-21
# 0  Attended          5  Attended          7  Attended          5  Attended  \
# 1  Attended          8  Attended          7  Attended          7  Attended
# 2    Missed          7    Missed          5    Missed          9    Missed
#
#    R-5-01-21  04-01-21  R-4-01-21  03-01-21  R-3-01-21  Avg_rating
# 0          8  Attended          9    Missed          6       6.875
# 1         10  Attended         10  Attended         10       8.875
# 2          8    Missed          5    Missed          7       7.000

# %%
df2["Flatten_rating"]= df2["Avg_rating"].astype(int)
df2.head(3)
# Out:
#    Student Roll Num     Type  10-01-21  R-10-01-21  09-01-21  R-9-01-21
# 0                 1  STUDENT  Attended           8  Attended          7  \
# 1                 2  STUDENT  Attended           9  Attended         10
# 2                 3  STUDENT    Missed           5    Missed         10
#
#    08-01-21  R-8-01-21  07-01-21  R-7-01-21  06-01-21  R-6-01-21  05-01-21
# 0  Attended          5  Attended          7  Attended          5  Attended  \
# 1  Attended          8  Attended          7  Attended          7  Attended
# 2    Missed          7    Missed          5    Missed          9    Missed
#
#    R-5-01-21  04-01-21  R-4-01-21  03-01-21  R-3-01-21  Avg_rating
# 0          8  Attended          9    Missed          6       6.875  \
# 1         10  Attended         10  Attended         10       8.875
# 2          8    Missed          5    Missed          7       7.000
#
#    Flatten_rating
# 0               6
# 1               8
# 2               7

# %%
#Bar chart for the visualization of Class 2 rating based on count

sns.countplot(x=df2['Flatten_rating'], data=df2, palette="tab10")


plt.title('Countplot of Average Rating class 2')


plt.show()

# %%
#The above bar chart visualizing student count's and their rating. Here out of 40% gave 6 rating
#speople gave 
# 23% of people gave 7 rating
#aroun 8% people gave rating 8

# %%
#Bar chart for the visualization of Class 2 rating based on type of the student

plt.figure(figsize=(10, 6))
sns.barplot(x=df2['Type'], y = df2["Flatten_rating"], palette="viridis")


plt.title('Barplot of Average Rating for class2 based on Types')


plt.show()

# %%
df2_rating = df2[(df2["Flatten_rating"]>=5) & (df2["Flatten_rating"]<=10)]
df2_rating
# Out:
#     Student Roll Num     Type  10-01-21  R-10-01-21  09-01-21  R-9-01-21
# 0                  1  STUDENT  Attended           8  Attended          7  \
# 1                  2  STUDENT  Attended           9  Attended         10
# 2                  3  STUDENT    Missed           5    Missed         10
# 3                  4  STUDENT  Attended           6  Attended          6
# 4                  5  WORKING  Attended           5  Attended          9
# ..               ...      ...       ...         ...       ...        ...
# 65                66   IGNORE    Missed           6    Missed         10
# 66                67  STUDENT    Missed           6    Missed          5
# 67                68  STUDENT  Attended           9  Attended          8
# 68                69  STUDENT  Attended          10  Attended          7
# 69                70  STUDENT  Attended           7  Attended          9
#
#     08-01-21  R-8-01-21  07-01-21  R-7-01-21  06-01-21  R-6-01-21  05-01-21
# ...

# %%
plt.figure(figsize=(12, 6))
sns.countplot(x=df2_rating['Type'], data =df2_rating, hue=df2_rating["Flatten_rating"])

plt.show()

# %%
#14 % of student belongs to "Student" type and 3% of student belong to "Working" type gave 8 rating
#35% of student belongs to type "Student" and 10% of student belongs to type "Working", 3% of student belongs to type "Ignore"
#and 3% of student belongs to type "Dropout" gave 7 ratings.

#These above students are considered to be satisfied

# %%
# Calculate the attendance count and missed count for each type
df2['Attended_Count'] = df2[df2 == 'Attended'].count(axis=1)
df2['Missed_Count'] = df2[df2 == 'Missed'].count(axis=1)
df2["total_sessions"] = len(df2.columns)
df2['Attended_Percentage'] = (df2['Attended_Count'] / df2['total_sessions']) * 100
df2['Missed_Percentage'] = (df2['Missed_Count'] / df2['total_sessions']) * 100

df2.head(3)
# Out:
#    Student Roll Num     Type  10-01-21  R-10-01-21  09-01-21  R-9-01-21
# 0                 1  STUDENT  Attended           8  Attended          7  \
# 1                 2  STUDENT  Attended           9  Attended         10
# 2                 3  STUDENT    Missed           5    Missed         10
#
#    08-01-21  R-8-01-21  07-01-21  R-7-01-21  ... R-4-01-21  03-01-21
# 0  Attended          5  Attended          7  ...         9    Missed  \
# 1  Attended          8  Attended          7  ...        10  Attended
# 2    Missed          7    Missed          5  ...         5    Missed
#
#   R-3-01-21  Avg_rating Flatten_rating  Attended_Count Missed_Count
# 0         6       6.875              6               7            1  \
# 1        10       8.875              8               8            0
# 2         7       7.000              7               0            8
#
#    total_sessions  Attended_Percentage  Missed_Percentage
# 0              22            31.818182           4.545455
# ...

# %%
student1= df2[df2['Type'] == 'STUDENT']
working1 = df2[df2['Type'] == 'WORKING']
ignore1 = df2[df2['Type'] == 'IGNORE']
dropout1 = df2[df2['Type'] == 'DROPOUT']

Types = ['student', 'working', 'ignore', 'dropout']

attended_percentage_df2 = [
    student1['Attended_Percentage'].mean(),
    working1['Attended_Percentage'].mean(),
    ignore1['Attended_Percentage'].mean(),
    dropout1['Attended_Percentage'].mean()
]

missed_percentage_df2 = [
    student1['Missed_Percentage'].mean(),
    working1['Missed_Percentage'].mean(),
    ignore1['Missed_Percentage'].mean(),
    dropout1['Missed_Percentage'].mean()
]


ignore.head()
# Out:
#     Student Roll Num    Type 10-01-21  R-10-01-21 09-01-21  R-9-01-21
# 13                14  IGNORE   Missed           5   Missed          7  \
# 65                66  IGNORE   Missed           6   Missed         10
#
#    08-01-21  R-8-01-21 07-01-21  R-7-01-21  ... R-4-01-21  03-01-21 R-3-01-21
# 13   Missed          5   Missed          9  ...         7  Attended         5  \
# 65   Missed          7   Missed          7  ...         5    Missed         9
#
#     Avg_rating Flatten_rating  Attended_Count Missed_Count  total_sessions
# 13       7.000              7               2            6              22  \
# 65       7.625              7               0            8              22
#
#     Attended_Percentage  Missed_Percentage
# 13             9.090909          27.272727
# 65             0.000000          36.363636
#
# [2 rows x 25 columns]

# %%
# Set the width of each bar
bar_width = 0.3

# Set the positions of the bars on the x-axis
r1 = range(len(Types))
r2 = [x + bar_width for x in r1]

# Create the bar plot
plt.figure(figsize=(15, 6))
plt.bar(r1, attended_percentage_df2, color="hotpink", width=bar_width, edgecolor="black", label='Attended')
plt.bar(r2, missed_percentage_df2, color="b", width=bar_width, edgecolor="black", label='Missed')

# Add labels, title, and legend
plt.xlabel('Type')
plt.ylabel('Percentage')
plt.title('Attendance Percentage by Type')
plt.xticks([r + bar_width/2 for r in range(len(Types))], Types)
plt.legend()
# Show the plot
plt.show()

# %%
y1 = np.array((student1['Attended_Percentage'].mean(),
    working1['Attended_Percentage'].mean(),
    ignore1['Attended_Percentage'].mean(),
    dropout1['Attended_Percentage'].mean()))

Types = ['student', 'working', 'ignore', 'dropout']
mycolors = ["y", "b", "r", "#4CAF50"]

plt.pie(y1, labels = Types, colors = mycolors, autopct='%1.1f%%')
plt.title('Pie Chart of Total classes attended for class2')
plt.show()

# %%
y1 = np.array((student1['Missed_Percentage'].mean(),
    working1['Missed_Percentage'].mean(),
    ignore1['Missed_Percentage'].mean(),
    dropout1['Missed_Percentage'].mean()))

Types = ['student', 'working', 'ignore', 'dropout']
mycolors = ["y", "b", "r", "#4CAF50"]

plt.pie(y1, labels = Types, colors = mycolors, autopct='%1.1f%%')
plt.title('Pie Chart of Total Missed for class2 dataset')
plt.show()

# %% [markdown]
# # Attendance based on each Type "Student", "Working", "Ignore" and "Dropout" for class2

# %%
fig, (ax1,ax2,ax3,ax4) = plt.subplots(1,4,figsize=(16, 6)) 
y31 = np.array((student1['Missed_Percentage'].mean(),
   student1['Attended_Percentage'].mean()))
y32 = np.array((working1['Missed_Percentage'].mean(), working1['Attended_Percentage'].mean()))
y33 = np.array((ignore1['Missed_Percentage'].mean(), ignore1['Attended_Percentage'].mean()))
y34 = np.array((dropout1['Missed_Percentage'].mean(), ignore1['Attended_Percentage'].mean()))

Types = ["Missed", "Attended"]
mycolors = ["y", "b"]
               
ax1.pie(y31, labels = Types, colors = mycolors,autopct='%1.1f%%')
ax2.pie(y32, labels = Types, colors = mycolors,autopct='%1.1f%%')
ax3.pie(y33, labels = Types, colors = mycolors,autopct='%1.1f%%')
ax4.pie(y34, labels = Types, colors = mycolors,autopct='%1.1f%%')
plt.show()
